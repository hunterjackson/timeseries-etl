# %%
import findspark
findspark.find()
import json  
from pyspark import SparkContext
from pyspark.streaming import StreamingContext  
from pyspark.streaming.kafka import KafkaUtils  
import os  
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-8:2.2.1 spark-shell' 
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-8_2.11:2.0.2 pyspark-shell'

# %%
sc = SparkContext(appName="timeseries-etl-test")
sc.setLogLevel("WARN")

# %%
ssc = StreamingContext(sc, 3)

# %%
kafkaStream = KafkaUtils.createStream(ssc=ssc, zkQuorum='localhost:2181', groupId='tet', topics={'raw':1})

# %%
parsed = kafkaStream.map(lambda v: json.loads(v[1]))  
parsed.count().map(lambda x:'Messages in batch: %s' % x).pprint()

# %%
ssc.start()  
ssc.awaitTermination()
# Out:
# -------------------------------------------
# Time: 2018-02-12 09:10:12
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-02-12 09:10:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-02-12 09:10:18
# -------------------------------------------
# Tweets in this batch: 26
#
# -------------------------------------------
# Time: 2018-02-12 09:10:21
# -------------------------------------------
# Tweets in this batch: 28
#
# -------------------------------------------
# Time: 2018-02-12 09:10:24
# -------------------------------------------
# Tweets in this batch: 29
#
# -------------------------------------------
# Time: 2018-02-12 09:10:27
# -------------------------------------------
# Tweets in this batch: 9
#
# -------------------------------------------
# Time: 2018-02-12 09:10:30
# -------------------------------------------
#
# ...
